# %% [markdown]
# # Intro to accessing NASA data
#
# ### Requirements
#
# - EDL account (username/password)
# - local netrc file with EDL credentials. See [this resource](https://www.labkey.org/Documentation/wiki-page.view?name=netrc)

# %%
import xarray as xr

# %%
print(xr.__version__)

# %%
url = "http://oceandata.sci.gsfc.nasa.gov/opendap/PACE_OCI/L3SMI/2024/0310/PACE_OCI.20240310.L3m.DAY.CHL.V2_0.chlor_a.4km.NRT.nc" # opendap url

# %%
ds = xr.open_dataset(url)

# %%
ds['chlor_a'].plot()
